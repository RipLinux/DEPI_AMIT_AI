# %%
list_one=[1,2,3,"Depi",[1,2,3]]
list_one[4][0]
# Out:
# 1

# %%
george = list("amit")
print(george)
# Out:
# ['a', 'm', 'i', 't']

# %%
list_1=["DEPI","machine learing","amit"]
list_1.append("deep learing")
print(list_1)
# Out:
# ['DEPI', 'machine learing', 'amit', 'deep learing']

# %%
list_1.insert(0,"NLP")
print(list_1)
# Out:
# ['NLP', 'NLP', 'DEPI', 'machine learing', 'amit', 'deep learing', 'A', 'n', 'a', 's']

# %%
list_1.extend("Anas")
print(list_1)
# Out:
# ['NLP', 'NLP', 'DEPI', 'machine learing', 'amit', 'deep learing', 'A', 'n', 'a', 's']

# %%
list_1.remove("NLP")
print(list_1)
# Out:
# ['NLP', 'DEPI', 'machine learing', 'amit', 'deep learing', 'A', 'n', 'a', 's']

# %%
print(list_1)
list_3=[1,2,3]
list_3.append(list_1.pop())
print(list_3)
# Out:
# ['NLP', 'DEPI', 'machine learing', 'amit', 'deep learing']
# [1, 2, 3, 'deep learing']

# %%
del list_3[0]
print(list_3)
# Out:
# [2, 3, 'deep learing']

# %%
myname = str(input("enter your name")).capitalize()
myage =  input("Enter your age")
print(f"my name is {myname}, and my age is {myage}")
# Out:
# my name is Anas, and my age is 20

# %%
itemlist=["word",2,3,4,5,6]
print(itemlist)
item_re= input("enter item to remove from list")
itemlist.remove(str (item_re))
print(f"item \"{item_re}\" deleted succesfully")
print(itemlist)
# Out:
# ['word', 2, 3, 4, 5, 6]
# item "word" deleted succesfully
# [2, 3, 4, 5, 6]

# %%
print (itemlist.index(5))
print (itemlist.count(2))
# Out:
# 3
# 1

# %%
itemsort= [1,2,7,5,62,6]
itemsort.sort()
itemsort.clear()
print(itemsort)
# Out:
# []

# %%
dict_1={"key1":"anas","key2":20}
print(dict_1["key1"])
# Out:
# anas

# %%
num1= float(input("enter first number"))
num2= float(input("enter second number"))

print(f"summation: {num1 + num2}")
print(f"subtraction: {num1 - num2}")
print(f"multiplication: {num1 * num2}")
print(f"division: {num1 / num2}")
# Out:
# summation: 5.0
# subtraction: -1.0
# multiplication: 6.0
# division: 0.6666666666666666

# %%
grade = float(input("enter your total grade:"))
if (grade <= 100 and grade >= 90):
    print("A")
elif (grade < 90 and grade >= 80):
    print("B")
elif (grade < 80 and grade >= 70):
    print("C")
elif (grade < 70 and grade >= 60):
    print("D")
else:
    print("F")
# Out:
# F
