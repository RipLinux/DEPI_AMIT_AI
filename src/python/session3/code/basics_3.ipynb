# %%
d = {'k1':1,'k2':3,'k3':5}
d.items()
# Out:
# dict_items([('k1', 1), ('k2', 3), ('k3', 5)])

# %%
for k,v in d.items():
    print(v)
    print(k)
    print(k,v)
# Out:
# 1
# k1
# k1 1
# 3
# k2
# k2 3
# 5
# k3
# k3 5

# %%
for i in range(6):
    if i== 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(6):
    if i== 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(6):
    if i== 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
def sum():
    pass

# %%
x = "global"
def fun(x):
    print("inside",x)

fun(10)

print("inside",x)
# Out:
# inside 10
# inside global

# %%
num1=int(input("enter first number"))
num2=int(input("enter second number"))
print (num1/num2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 num1=int(input("enter first number"))
#       2 num2=int(input("enter second number"))
# ----> 3 print (num1/num2)
#
# ZeroDivisionError: division by zero

# %%
try:
    num1=int(input("enter first number"))
    num2=int(input("enter second number"))
    print (num1/num2)
except Exception as error:
    print(error)
# Out:
# division by zero

# %%
try:
    print(z)
except NameError:
    print("z isn't defined")
# Out:
# z isn't defined

# %%
try:
    print(z)
except :
    print("z isn't defined")
# Out:
# z isn't defined

# %%
try:
    z = 10
    print(z)
except :
    print("z isn't defined")
else: 
    print("thanks")
finally:
    print("done")
# Out:
# 10
# thanks
# done

# %%
import random
n=int(random.random()*10000)
n
# Out:
# 5193

# %%
random.randint(1,10)
# Out:
# 4

# %%
list1 = ['anas1','anas2','anas3','anas']
random.choice(list1)
# Out:
# 'anas2'

# %%
def function1():
    print("hello")
function1()
# Out:
# hello

# %%
## from fun import getinfo
getinfo("ahmed",50)
# Out:
# "my name is anas, and I'm 20 years old"

# %%
def userinfo(name = "name",age= 00):
    return(print(f"NAME IS {name}, AGE {age}"))
userinfo()
# Out:
# NAME IS name, AGE 0

# %%
def userinfo(name ,age= 00):
    return(print(f"NAME IS {name}, AGE {age}"))
userinfo("z")
# Out:
# NAME IS z, AGE 0

# %%
def userinfo(name ,age= 00):
    return(print(f"AGE {age}"))
userinfo("z")
# Out:
# AGE 0

# %%
from fun import main 

main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 from fun import main
#       2
#       3 main()
#
# ImportError: cannot import name 'main' from 'fun' (c:\Users\ديل\Desktop\Courses\DEPI,AMIT,Microsoft Machine Learning Course\Projects\DEPI_AMIT_AI\src\python\session3\code\fun.py)

# %%
def function2 (*name):
    print(name)
    print(type(name))

function2(["test",True,23])
# Out:
# (['test', True, 23],)
# <class 'tuple'>
