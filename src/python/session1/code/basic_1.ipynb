# %% [markdown]
# We working with google style coding (that is the tecqnique the companies work with it)

# %%
print("New Hello:",2026)
# comment 
'''
comment
comment
comment
comment
'''
# Out:
# New Hello: 2026
# '\ncomment\ncomment\ncomment\ncomment\n'

# %%
x=5
type(x)
# Out:
# int

# %%
round="DEPI-R5"
print("Round: {0}, Number: {1}".format(round,5))
print(f"Round: {round}, number: {5}")
# Out:
# Round: DEPI-R5, Number: 5
# Round: DEPI-R5, number: 5

# %%
name = "Anas_Sayed"
age = 20
course_name = "AMIT-DEPI-R5"
print (f"My name is: {name} , and I'm {age} years old. I'm participate in {course_name}")
# Out:
# My name is: Anas_Sayed , and I'm 20 years old. I'm participate in AMIT-DEPI-R5
# ''

# %%
inc_name = "amit learning"
print(inc_name[-9:-1:1])
# Out:
#  learnin

# %%
# Out:
# 1

# %%
# Out:
# ['a', 'm', 'i', 't']
