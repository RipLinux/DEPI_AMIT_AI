# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, 7, 9], index = ['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    1
# b    3
# c    5
# d    7
# e    9
# dtype: int64

# %%
data = {
    'index': ['a', 'b', 'c', 'd', 'e'],
    'std_id': [1, 3, 5, 7, 9],
    'department': ['Math', 'Physics', 'Chemistry', 'Biology', 'Computer Science']
}
df = pd.DataFrame(data)

# %%
display(df)
# Out:
#   index  std_id        department
# 0     a       1              Math
# 1     b       3           Physics
# 2     c       5         Chemistry
# 3     d       7           Biology
# 4     e       9  Computer Science

# %%
columns = ['index', 'student_id', 'departments']
df.columns = columns
display(df)
# Out:
#   index  student_id       departments
# 0     a           1              Math
# 1     b           3           Physics
# 2     c           5         Chemistry
# 3     d           7           Biology
# 4     e           9  Computer Science

# %%
df[['index', 'departments','student_id']].dtypes
# Out:
# index          str
# departments    str
# dtype: object

# %%
df['student_id'] = df['student_id'].astype('category')
df[['index', 'departments','student_id']].dtypes
# Out:
# index               str
# departments         str
# student_id     category
# dtype: object

# %%
df.tail(2)
# Out:
#   index student_id       departments
# 3     d          7           Biology
# 4     e          9  Computer Science

# %%
df.head(-1)
# Out:
#   index student_id departments
# 0     a          1        Math
# 1     b          3     Physics
# 2     c          5   Chemistry
# 3     d          7     Biology

# %%
print(df.head(-1))
# Out:
#   index student_id departments
# 0     a          1        Math
# 1     b          3     Physics
# 2     c          5   Chemistry
# 3     d          7     Biology

# %%
df.describe()
# Out:
#        index  student_id departments
# count      5           5           5
# unique     5           5           5
# top        a           1        Math
# freq       1           1           1

# %%
df.describe(include='category')
# Out:
#         student_id
# count            5
# unique           5
# top              1
# freq             1

# %%
df['student_id'].unique()
# Out:
# [1, 3, 5, 7, 9]
# Categories (5, int64): [1, 3, 5, 7, 9]

# %%
df['student_id'].nunique()
# Out:
# 5

# %%
df['student_id'].idxmax()
# Out:
# 4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        5 non-null      str
#  1   student_id   5 non-null      category
#  2   departments  5 non-null      str
# dtypes: category(1), str(2)
# memory usage: 257.0 bytes

# %%
df['index'].sum
# Out:
# <bound method Series.sum of 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# Name: index, dtype: str>

# %%
x = df.values
type(x)
# Out:
# numpy.ndarray

# %%
display(df)
# Out:
#   index student_id       departments
# 0     a          1              Math
# 1     b          3           Physics
# 2     c          5         Chemistry
# 3     d          7           Biology
# 4     e          9  Computer Science

# %%
df.replace('Math','anas',inplace=True)
df
# Out:
#   index student_id       departments
# 0     a          1              anas
# 1     b          3           Physics
# 2     c          5         Chemistry
# 3     d          7           Biology
# 4     e          9  Computer Science

# %%
df.departments= df.departments.map(lambda x: x.upper())

# %%
df
# Out:
#   index student_id       departments
# 0     a          1              ANAS
# 1     b          3           PHYSICS
# 2     c          5         CHEMISTRY
# 3     d          7           BIOLOGY
# 4     e          9  COMPUTER SCIENCE
